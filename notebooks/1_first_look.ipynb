# %%
import json
import os

import pandas as pd

# %%
train_folder = "../data/train"
sample_sub = "../data/sample_submission.csv"

# %%
sample_sub_df = pd.read_csv(sample_sub)

# %%
sample_sub_df
# Out:
#                id                                         cell_order
# 0  0009d135ece78d  ddfd239c c6cd22db 1372ae9b 90ed07ab 7f388a41 2...
# 1  0010483c12ba9b  54c7cab3 fe66203e 7844d5f8 5ce8863c 4a0777c4 4...
# 2  0010a919d60e4f  aafc3d23 80e077ec b190ebb4 ed415c3c 322850af c...
# 3  0028856e09c5b7                012c9d02 d22526d1 3ae7ece3 eb293dfc

# %%
sample_sub_df.iloc[0]["cell_order"]
# Out:
# 'ddfd239c c6cd22db 1372ae9b 90ed07ab 7f388a41 2843a25a 06dbf8cf f9893819 ba55e576 39e937ec e25aa9bd 0a226b6a 8cb8d28a'

# %%
index = 1
example = train_folder + "/" + os.listdir(train_folder)[index]
example_dict = json.loads(open(example, "r").read())

# %%
example_dict
# Out:
# {'cell_type': {'c417225b': 'code',
#   '51e3cd89': 'code',
#   '2600b4eb': 'code',
#   '75b65993': 'code',
#   'cf195f8b': 'code',
#   '25699d02': 'code',
#   'de148b56': 'code',
#   '9901472c': 'code',
#   '10377ef8': 'code',
#   '1f462e2f': 'code',
#   'fceeb3e6': 'code',
#   '2af2a41a': 'code',
#   '91e68f13': 'code',
#   '9216a113': 'code',
#   '63753f10': 'code',
#   'd5aee1e4': 'code',
#   'dc8a39a5': 'code',
#   '3d0a28c2': 'code',
#   '0eea9701': 'code',
#   'a6f8f9f1': 'code',
#   '7223cfc2': 'code',
#   'df6b3ccb': 'code',
#   'a9b266d2': 'code',
#   '3e17f424': 'code',
#   '42f0c365': 'code',
#   'cc8d23d8': 'code',
#   'ad42abc1': 'code',
#   '7894c4e8': 'code',
#   'cc1add42': 'code',
#   '16b0d436': 'code',
#   'a3e791de': 'code',
#   '02ef0932': 'code',
#   '03441163': 'code',
#   'd429a743': 'code',
#   '4d5ebd46': 'code',
#   '3adcd0f8': 'code',
#   'd8f4dfe0': 'code',
#   'd47d3338': 'code',
#   'c5b89474': 'code',
#   'b5ef409a': 'code',
#   '7bb6803b': 'code',
# ...
